# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('used_cars_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       brand    model  price (eur)                     engine  \
# 0           0        SEAT    Ibiza         8990      SC 1.2 TSI 90cv Style
# 1           1     Hyundai      i30         9990       1.6 CRDi 110cv Tecno
# 2           2         BMW  Serie 5        13490               530d Touring
# 3           3  Volkswagen     Golf        24990  GTI 2.0 TSI 169kW (230CV)
# 4           4        Opel    Corsa        10460       1.4 Expression 90 CV
#
#    year  mileage (kms)      fuel     gearbox    location
# 0  2016          67000  Gasolina      Manual  Granollers
# 1  2014         104868    Diésel      Manual  Viladecans
# 2  2011         137566    Diésel  Automatica  Viladecans
# 3  2018          44495  Gasolina      Manual  Viladecans
# 4  2016          69800  Gasolina      Manual  Sabadell 1

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# brand            0
# model            0
# price (eur)      0
# engine           0
# year             0
# mileage (kms)    0
# fuel             0
# gearbox          0
# location         0
# dtype: int64

# %%
df.shape
# Out:
# (792, 10)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Unnamed: 0       brand    model  price (eur)                     engine  \
# 0           0        SEAT    Ibiza         8990      SC 1.2 TSI 90cv Style
# 1           1     Hyundai      i30         9990       1.6 CRDi 110cv Tecno
# 2           2         BMW  Serie 5        13490               530d Touring
# 3           3  Volkswagen     Golf        24990  GTI 2.0 TSI 169kW (230CV)
# 4           4        Opel    Corsa        10460       1.4 Expression 90 CV
#
#    year  mileage (kms)      fuel     gearbox    location
# 0  2016          67000  Gasolina      Manual  Granollers
# 1  2014         104868    Diésel      Manual  Viladecans
# 2  2011         137566    Diésel  Automatica  Viladecans
# 3  2018          44495  Gasolina      Manual  Viladecans
# 4  2016          69800  Gasolina      Manual  Sabadell 1

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
# pd.set_option('display.max_column',None)

# %%
df.head()
# Out:
#         brand    model  price (eur)                     engine  year  \
# 0        SEAT    Ibiza         8990      SC 1.2 TSI 90cv Style  2016
# 1     Hyundai      i30         9990       1.6 CRDi 110cv Tecno  2014
# 2         BMW  Serie 5        13490               530d Touring  2011
# 3  Volkswagen     Golf        24990  GTI 2.0 TSI 169kW (230CV)  2018
# 4        Opel    Corsa        10460       1.4 Expression 90 CV  2016
#
#    mileage (kms)      fuel     gearbox    location
# 0          67000  Gasolina      Manual  Granollers
# 1         104868    Diésel      Manual  Viladecans
# 2         137566    Diésel  Automatica  Viladecans
# 3          44495  Gasolina      Manual  Viladecans
# 4          69800  Gasolina      Manual  Sabadell 1

# %%
def bar(plot):
    plt.figure(figsize=(10,9))
    sns.barplot(x=plot,y=df['price (eur)'])
    plt.xticks(rotation='vertical')
    plt.show()
    return bar

# %%
bar(df['brand'])
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
def scatter(plot):
    plt.figure(figsize=(10,5))
    sns.scatterplot(x=plot,y=df['price (eur)'])
    plt.xticks(rotation='vertical')
    plt.show()
    return scatter

# %%
scatter(df['brand'])
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
def count(plot):
    plt.figure(figsize=(10,5))
    sns.countplot(plot)
    plt.xticks(rotation='vertical')
    plt.show()
    return count

# %%
df['brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
df.head()
# Out:
#         brand    model  price (eur)                     engine  year  \
# 0        SEAT    Ibiza         8990      SC 1.2 TSI 90cv Style  2016
# 1     Hyundai      i30         9990       1.6 CRDi 110cv Tecno  2014
# 2         BMW  Serie 5        13490               530d Touring  2011
# 3  Volkswagen     Golf        24990  GTI 2.0 TSI 169kW (230CV)  2018
# 4        Opel    Corsa        10460       1.4 Expression 90 CV  2016
#
#    mileage (kms)      fuel     gearbox    location
# 0          67000  Gasolina      Manual  Granollers
# 1         104868    Diésel      Manual  Viladecans
# 2         137566    Diésel  Automatica  Viladecans
# 3          44495  Gasolina      Manual  Viladecans
# 4          69800  Gasolina      Manual  Sabadell 1

# %%
bar(df['model'])
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.pairplot(df, hue="price (eur)", diag_kind="hist")
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
scatter(df['model'])
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df['model'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='model'>

# %%
df.head(4)
# Out:
#         brand    model  price (eur)                     engine  year  \
# 0        SEAT    Ibiza         8990      SC 1.2 TSI 90cv Style  2016
# 1     Hyundai      i30         9990       1.6 CRDi 110cv Tecno  2014
# 2         BMW  Serie 5        13490               530d Touring  2011
# 3  Volkswagen     Golf        24990  GTI 2.0 TSI 169kW (230CV)  2018
#
#    mileage (kms)      fuel     gearbox    location
# 0          67000  Gasolina      Manual  Granollers
# 1         104868    Diesel      Manual  Viladecans
# 2         137566    Diesel  Automatica  Viladecans
# 3          44495  Gasolina      Manual  Viladecans

# %%
df['engine'].unique()
# Out:
# array(['SC 1.2 TSI 90cv Style', '1.6 CRDi 110cv Tecno', '530d Touring',
#        'GTI 2.0 TSI 169kW (230CV)', '1.4 Expression 90 CV',
#        'SC 1.2 TSI 105cv FR', '3.8 Rubicon Auto',
#        '1.6 GDi 97kW (132CV) Basic 4x2', '2.0L eD4 110kW (150CV) 4x2 SE',
#        '1.5 eTSI 110kW DSG-7 S&S Xcellence Go M', '5p 1.0G ACENTA',
#        'Panorama Lounge 1.6 Multijet 105cv E5+', '118i',
#        '2.0 TSI 221kW (300CV) DSG-6 St&Sp CUPRA',
#        '1.0 Ecoboost 92kW ST-Line', 'PureTech 82cv S&S ETG Shine',
#        '1.8 125H Advance', '1.5 110 Active Tech',
#        '1.0 TGDI Link Fastback', 'Edition 1.6 TDI CR 115CV BMT',
#        '320d Gran Turismo', '1.0 EcoTSI 95cv Style Connect',
#        '5P STYLE 1.6 BlueHDi 100', 'Prestige TCE 92kW (125CV) 4X2',
#        '1.0 EcoTSI 85kW (115CV) FR Plus', '2.2 D-4D Advance 4x2',
#        'COOPER SD PACEMAN automático', '318d Touring',
#        'Access 1.6 HDI 111 FAP', 'Business TCe 55kW (75CV) -18',
# ...

# %%
bar(df['year'])
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
bar(df['mileage (kms)'])
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df['fuel'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='fuel'>

# %%
df['fuel'] = df['fuel'].str.replace('Diésel','Diesel')

# %%
df['fuel'].unique()
# Out:
# array(['Gasolina', 'Diesel', 'Híbrido', 'GLP', 'Eléctrico'], dtype=object)

# %%
df['fuel'] = df['fuel'].str.replace('Eléctrico','Electric')

# %%
df.drop(['location'],axis=1,inplace=True)

# %%
df.head()
# Out:
#         brand    model  price (eur)                     engine  year  \
# 0        SEAT    Ibiza         8990      SC 1.2 TSI 90cv Style  2016
# 1     Hyundai      i30         9990       1.6 CRDi 110cv Tecno  2014
# 2         BMW  Serie 5        13490               530d Touring  2011
# 3  Volkswagen     Golf        24990  GTI 2.0 TSI 169kW (230CV)  2018
# 4        Opel    Corsa        10460       1.4 Expression 90 CV  2016
#
#    mileage (kms)      fuel     gearbox
# 0          67000  Gasolina      Manual
# 1         104868    Diesel      Manual
# 2         137566    Diesel  Automatica
# 3          44495  Gasolina      Manual
# 4          69800  Gasolina      Manual

# %%
bar(df['gearbox'])
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df.dtypes
# Out:
# brand            object
# model            object
# price (eur)       int64
# engine           object
# year              int64
# mileage (kms)     int64
# fuel             object
# gearbox          object
# dtype: object

# %%
sns.histplot(np.log(df['price (eur)']))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price (eur)', ylabel='Count'>

# %%
df[df['mileage (kms)']>(df['mileage (kms)'].mean()+3*df['mileage (kms)'].std())]
# Out:
# Empty DataFrame
# Columns: [brand, model, price (eur), engine, year, mileage (kms), fuel, gearbox]
# Index: []

# %%
df[df['year']>(df['year'].mean()+3*df['year'].std())]
# Out:
# Empty DataFrame
# Columns: [brand, model, price (eur), engine, year, mileage (kms), fuel, gearbox]
# Index: []

# %%
df.head()
# Out:
#         brand    model  price (eur)                     engine  year  \
# 0        SEAT    Ibiza         8990      SC 1.2 TSI 90cv Style  2016
# 1     Hyundai      i30         9990       1.6 CRDi 110cv Tecno  2014
# 2         BMW  Serie 5        13490               530d Touring  2011
# 3  Volkswagen     Golf        24990  GTI 2.0 TSI 169kW (230CV)  2018
# 4        Opel    Corsa        10460       1.4 Expression 90 CV  2016
#
#    mileage (kms)      fuel     gearbox
# 0          67000  Gasolina      Manual
# 1         104868    Diesel      Manual
# 2         137566    Diesel  Automatica
# 3          44495  Gasolina      Manual
# 4          69800  Gasolina      Manual

# %%
df['engine'] = df['engine'].apply(lambda x: ' '.join(x.split()[0:3]))

# %%
df['engine'].unique()
# Out:
# array(['SC 1.2 TSI', '1.6 CRDi 110cv', '530d Touring', 'GTI 2.0 TSI',
#        '1.4 Expression 90', '3.8 Rubicon Auto', '1.6 GDi 97kW',
#        '2.0L eD4 110kW', '1.5 eTSI 110kW', '5p 1.0G ACENTA',
#        'Panorama Lounge 1.6', '118i', '2.0 TSI 221kW',
#        '1.0 Ecoboost 92kW', 'PureTech 82cv S&S', '1.8 125H Advance',
#        '1.5 110 Active', '1.0 TGDI Link', 'Edition 1.6 TDI',
#        '320d Gran Turismo', '1.0 EcoTSI 95cv', '5P STYLE 1.6',
#        'Prestige TCE 92kW', '1.0 EcoTSI 85kW', '2.2 D-4D Advance',
#        'COOPER SD PACEMAN', '318d Touring', 'Access 1.6 HDI',
#        'Business TCe 55kW', 'PureTech 60KW (83CV)', '1.6D 115D Business',
#        '2.0i Executive Plus', '1.0 EcoBoost 100cv',
#        'Active 1.2L PureTech', 'Van 1.6 TDCi', '1.2 Turbo Ultimate',
#        'M4 COMPETITION', '2.0 TDI 150CV', 'Kombi PRO Corto',
#        'Advance 1.4 TSI', 'TEPEE Access BlueHDi', 'PureTech 81KW (110CV)',
#        '1.0 MPI 59kW', '1.4 T 103kW', '1.5 dCi EDICIÓN', 'A 180',
# ...

# %%
df.head()
# Out:
#         brand    model  price (eur)             engine  year  mileage (kms)  \
# 0        SEAT    Ibiza         8990         SC 1.2 TSI  2016          67000
# 1     Hyundai      i30         9990     1.6 CRDi 110cv  2014         104868
# 2         BMW  Serie 5        13490       530d Touring  2011         137566
# 3  Volkswagen     Golf        24990        GTI 2.0 TSI  2018          44495
# 4        Opel    Corsa        10460  1.4 Expression 90  2016          69800
#
#        fuel     gearbox
# 0  Gasolina      Manual
# 1    Diesel      Manual
# 2    Diesel  Automatica
# 3  Gasolina      Manual
# 4  Gasolina      Manual

# %%
x = df.drop(['price (eur)'],axis=1)
y = np.log(df['price (eur)'])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.2,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor,AdaBoostRegressor
from xgboost import XGBRFRegressor
from sklearn.tree import DecisionTreeRegressor
from catboost import CatBoostRegressor

# %%
xtrain.head(1)
# Out:
#     brand  model        engine  year  mileage (kms)    fuel gearbox
# 620  Opel  Astra  1.6 CDTi S/S  2019          22900  Diesel  Manual

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[0,1,2,5,6])
],remainder='passthrough')


step2 = Ridge()
pipe = Pipeline([
    ('step1',step1),
    ('step2', step2)
])

pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('r2 scores',r2_score(ytest,y_pred))
print('mean absoulte error',mean_absolute_error(ytest,y_pred))
# Out:
# r2 scores 0.7753451576344953
# mean absoulte error 0.1241433213317671
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score, mean_absolute_error

# Define the pipeline
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore'), [0, 1, 2, 5, 6])
], remainder='passthrough')

step2 = Ridge()
pipe1 = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Define the parameter grid for Ridge regression
param_grid = {
    'step2__alpha': [0.1, 1, 10],  # Adjust the range of alpha values as needed
}

# Perform grid search with cross-validation
grid_search = GridSearchCV(pipe1, param_grid, cv=5, scoring='neg_mean_absolute_error')
grid_search.fit(xtrain, ytrain)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# Use the best model to make predictions on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(xtest)

# Evaluate the model performance
print('r2 score:', r2_score(ytest, y_pred))
print('mean absolute error:', mean_absolute_error(ytest, y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [0, 1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ...

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[0,1,2,5,6])
],remainder='passthrough')


step2 = XGBRFRegressor()
pipe = Pipeline([
    ('step1',step1),
    ('step2', step2)
])

pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('r2 scores',r2_score(ytest,y_pred))
print('mean absoulte error',mean_absolute_error(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# r2 scores 0.529635150698325
# mean absoulte error 0.19718817795794738
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBRFRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# Define the pipeline
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first', handle_unknown='ignore'), [0, 1, 2, 5, 6])
], remainder='passthrough')

step2 = XGBRFRegressor()
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Define the parameter grid for XGBoost
param_grid = {
    'step2__n_estimators': [100, 200, 300],  # Adjust the range of n_estimators as needed
    'step2__learning_rate': [0.01, 0.1, 0.2],  # Adjust the range of learning_rate as needed
}

# Perform grid search with cross-validation
grid_search = GridSearchCV(pipe, param_grid, cv=5, scoring='neg_mean_absolute_error')
grid_search.fit(xtrain, ytrain)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# Use the best model to make predictions on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(xtest)

# Evaluate the model performance
print('r2 score:', r2_score(ytest, y_pred))
print('mean absolute error:', mean_absolute_error(ytest, y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# ...

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[0,1,2,5,6])
],remainder='passthrough')


step2 = AdaBoostRegressor()
pipe = Pipeline([
    ('step1',step1),
    ('step2', step2)
])

pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('r2 scores',r2_score(ytest,y_pred))
print('mean absoulte error',mean_absolute_error(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 scores 0.47760827706319475
# mean absoulte error 0.21383334000365187
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[0,1,2,5,6])
],remainder='passthrough')


step2 = RandomForestRegressor()
pipe = Pipeline([
    ('step1',step1),
    ('step2', step2)
])

pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('r2 scores',r2_score(ytest,y_pred))
print('mean absoulte error',mean_absolute_error(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# r2 scores 0.6526094448216625
# mean absoulte error 0.16627603084722425
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[0,1,2,5,6])
],remainder='passthrough')


step2 = Lasso()
pipe = Pipeline([
    ('step1',step1),
    ('step2', step2)
])

pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('r2 scores',r2_score(ytest,y_pred))
print('mean absoulte error',mean_absolute_error(ytest,y_pred))
# Out:
# r2 scores 0.07466376722077772
# mean absoulte error 0.28820654412184704
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[0,1,2,5,6])
],remainder='passthrough')


step2 = DecisionTreeRegressor()
pipe = Pipeline([
    ('step1',step1),
    ('step2', step2)
])

pipe.fit(xtrain,ytrain)
y_pred = pipe.predict(xtest)
print('r2 scores',r2_score(ytest,y_pred))
print('mean absoulte error',mean_absolute_error(ytest,y_pred))
# Out:
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# r2 scores 0.5300250863136071
# mean absoulte error 0.19583644622142432

# %%
import pickle

# Assuming 'best_model' is your trained XGBoost pipeline
# You should replace 'best_model' with the actual variable containing your trained model

# Save the model to a file
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('data.pkl', 'wb') as file:
    pickle.dump(xtrain, file)

# %%
import pickle

# Load the saved model from file
with open('model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# Now, 'loaded_model' contains your trained XGBoost pipeline

# %%
pred = loaded_model.predict(xtest)
print(r2_score(ytest,pred))
# Out:
# 0.7942179842173775
# C:\Users\Ghost Codm\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\preprocessing\_encoders.py:228: UserWarning: Found unknown categories in columns [1, 2] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
xtrain.head()
# Out:
#           brand            model                 engine  year  mileage (kms)  \
# 620        Opel            Astra           1.6 CDTi S/S  2019          22900
# 333  Volkswagen             Golf        Advance 1.6 TDI  2013         136000
# 42      Citroen       C3 Picasso  PureTech 81KW (110CV)  2017          78453
# 766        Alfa  Romeo Giulietta         1.6 JTDm 120cv  2016          90300
# 761     Citroen      C3 Aircross   PureTech 60kW (82CV)  2018          63534
#
#          fuel     gearbox
# 620    Diesel      Manual
# 333    Diesel  Automatica
# 42   Gasolina      Manual
# 766    Diesel  Automatica
# 761  Gasolina      Manual
